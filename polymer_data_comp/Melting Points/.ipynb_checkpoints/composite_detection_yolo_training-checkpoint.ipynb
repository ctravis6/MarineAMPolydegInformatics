# %%
# %pip install -r yolov5/requirements.txt 
# %pip install sklearn scikit-image azureml-core
# Out:
# Collecting matplotlib>=3.2.2
#   Using cached matplotlib-3.4.2-cp38-cp38-win_amd64.whl (7.1 MB)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.20.3-cp38-cp38-win_amd64.whl (13.7 MB)
# Collecting opencv-python>=4.1.2
#   Using cached opencv_python-4.5.2.52-cp38-cp38-win_amd64.whl (34.7 MB)
# Collecting Pillow
#   Using cached Pillow-8.2.0-cp38-cp38-win_amd64.whl (2.2 MB)
# Collecting PyYAML>=5.3.1
#   Using cached PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.6.3-cp38-cp38-win_amd64.whl (32.7 MB)
# Collecting torch>=1.7.0
#   Using cached torch-1.8.1-cp38-cp38-win_amd64.whl (190.5 MB)
# Collecting torchvision>=0.8.1
#   Using cached torchvision-0.9.1-cp38-cp38-win_amd64.whl (852 kB)
# Collecting tqdm>=4.41.0
#   Using cached tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Collecting tensorboard>=2.4.1
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# Collecting pandas
#   Using cached pandas-1.2.4-cp38-cp38-win_amd64.whl (9.3 MB)
# Collecting thop
#   Using cached thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# Collecting pycocotools>=2.0
#   Using cached pycocotools-2.0.2-cp38-cp38-win_amd64.whl
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp38-cp38-win_amd64.whl (51 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: setuptools>=18.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from pycocotools>=2.0->-r yolov5/requirements.txt (line 29)) (52.0.0.post20210125)
# Collecting cython>=0.27.3
#   Using cached Cython-0.29.23-cp38-cp38-win_amd64.whl (1.7 MB)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.30.0-py2.py3-none-any.whl (146 kB)
# Collecting absl-py>=0.4
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting protobuf>=3.6.0
#   Using cached protobuf-3.17.0-py2.py3-none-any.whl (173 kB)
# Collecting grpcio>=1.24.3
#   Using cached grpcio-1.37.1-cp38-cp38-win_amd64.whl (3.1 MB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 15)) (0.36.2)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.0.0-py3-none-any.whl (288 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting typing-extensions
#   Using cached typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: six in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 15)) (1.15.0)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 15)) (2020.12.5)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Installing collected packages: urllib3, pyasn1, idna, chardet, rsa, requests, pyasn1-modules, oauthlib, cachetools, typing-extensions, requests-oauthlib, pytz, Pillow, numpy, kiwisolver, google-auth, cycler, werkzeug, torch, tensorboard-plugin-wit, tensorboard-data-server, scipy, protobuf, pandas, matplotlib, markdown, grpcio, google-auth-oauthlib, cython, absl-py, tqdm, torchvision, thop, tensorboard, seaborn, PyYAML, pycocotools, opencv-python
# Successfully installed Pillow-8.2.0 PyYAML-5.4.1 absl-py-0.12.0 cachetools-4.2.2 chardet-4.0.0 cycler-0.10.0 cython-0.29.23 google-auth-1.30.0 google-auth-oauthlib-0.4.4 grpcio-1.37.1 idna-2.10 kiwisolver-1.3.1 markdown-3.3.4 matplotlib-3.4.2 numpy-1.20.3 oauthlib-3.1.0 opencv-python-4.5.2.52 pandas-1.2.4 protobuf-3.17.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycocotools-2.0.2 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 rsa-4.7.2 scipy-1.6.3 seaborn-0.11.1 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 thop-0.0.31.post2005241907 torch-1.8.1 torchvision-0.9.1 tqdm-4.60.0 typing-extensions-3.10.0.0 urllib3-1.26.4 werkzeug-2.0.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting scikit-image
#   Using cached scikit_image-0.18.1-cp38-cp38-win_amd64.whl (12.2 MB)
# Collecting azureml-core
#   Using cached azureml_core-1.28.0-py3-none-any.whl (2.2 MB)
# Collecting PyJWT<3.0.0
#   Using cached PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Using cached azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Using cached ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Using cached cryptography-3.4.7-cp36-abi3-win_amd64.whl (1.6 MB)
# Collecting contextlib2<1.0.0
#   Using cached contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting docker<5.0.0
#   Using cached docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting msrestazure>=0.4.33
#   Using cached msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting backports.tempfile
#   Using cached backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Using cached azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting jmespath<1.0.0
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ndg-httpsclient
#   Using cached ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting SecretStorage<4.0.0
#   Using cached SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Using cached azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting adal>=1.2.0
#   Using cached adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Using cached azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from azureml-core) (2.25.1)
# Requirement already satisfied: urllib3>=1.23 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from azureml-core) (1.26.4)
# Collecting jsonpickle<3.0.0
#   Using cached jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Using cached azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl<21.0.0
#   Using cached pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: pytz in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from azureml-core) (2021.1)
# Collecting pathspec<1.0.0
#   Using cached pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Using cached azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Using cached azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from azureml-core) (2.8.1)
# Collecting msrest<1.0.0,>=0.5.1
#   Using cached msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core) (2.20)
# Collecting websocket-client>=0.32.0
#   Using cached websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: pywin32==227 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from docker<5.0.0->azureml-core) (227)
# Requirement already satisfied: six>=1.4.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from docker<5.0.0->azureml-core) (1.15.0)
# Collecting isodate>=0.6.0
#   Using cached isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core) (2020.12.5)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core) (3.1.0)
# Collecting ruamel.yaml.clib>=0.1.2
#   Using cached ruamel.yaml.clib-0.2.2-cp38-cp38-win_amd64.whl (120 kB)
# Collecting jeepney>=0.6
#   Using cached jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.1.1-cp38-cp38-win_amd64.whl (4.3 MB)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2021.4.8-py3-none-any.whl (165 kB)
# Requirement already satisfied: scipy>=1.0.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from scikit-image) (1.6.3)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from scikit-image) (1.20.3)
# Collecting imageio>=2.3.0
#   Using cached imageio-2.9.0-py3-none-any.whl (3.3 MB)
# Collecting networkx>=2.0
#   Using cached networkx-2.5.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from scikit-image) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.1)
# Collecting decorator<5,>=4.3
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.2-cp38-cp38-win_amd64.whl (6.9 MB)
# Collecting backports.weakref
#   Using cached backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\users\kadis\anaconda3\envs\yolov5\lib\site-packages (from ndg-httpsclient->azureml-core) (0.4.8)
# Collecting joblib>=0.11
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: PyJWT, isodate, cryptography, msrest, adal, websocket-client, threadpoolctl, ruamel.yaml.clib, pyopenssl, msrestazure, joblib, jeepney, decorator, backports.weakref, azure-common, tifffile, SecretStorage, scikit-learn, ruamel.yaml, PyWavelets, pathspec, networkx, ndg-httpsclient, jsonpickle, jmespath, imageio, docker, contextlib2, backports.tempfile, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, sklearn, scikit-image, azureml-core
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.0.6
#     Uninstalling decorator-5.0.6:
#       Successfully uninstalled decorator-5.0.6
# Successfully installed PyJWT-2.1.0 PyWavelets-1.1.1 SecretStorage-3.3.1 adal-1.2.7 azure-common-1.1.27 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.28.0 backports.tempfile-1.0 backports.weakref-1.0.post1 contextlib2-0.6.0.post1 cryptography-3.4.7 decorator-4.4.2 docker-4.4.4 imageio-2.9.0 isodate-0.6.0 jeepney-0.6.0 jmespath-0.10.0 joblib-1.0.1 jsonpickle-2.0.0 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 networkx-2.5.1 pathspec-0.8.1 pyopenssl-20.0.1 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 scikit-image-0.18.1 scikit-learn-0.24.2 sklearn-0.0 threadpoolctl-2.1.0 tifffile-2021.4.8 websocket-client-0.59.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from util import labeledImage, normalize_coordinates, convert_to_yolo_format
from sklearn.model_selection import train_test_split
import os, shutil, yaml

# %%
source_images_dir = 'C:/Users/kadis/OneDrive/Documents/Hack_Week/UW_Boeing_Hackweek_data/boeing_data_roi_trainset/'
source_labels_dir = 'C:/Users/kadis/OneDrive/Documents/Hack_Week/UW_Boeing_Hackweek_data/boeing_data_roi_trainset/labels/'

labeled_images = []
tag = 'composites' 

for file in os.listdir(source_images_dir):
    # find all jpeg file and it's ImageJ label
    if file.endswith(".png"):
        image_path = os.path.join(source_images_dir, file)
        label_path = os.path.join(source_labels_dir, file.split('.')[0] + '.txt')
        labeled_images.append(labeledImage(image_path))
        labeled_images[-1].add_labels_from_file(tag, label_path)

# %%
train_and_val_set, test_set = train_test_split(labeled_images, test_size=0.1)
train_set, val_set = train_test_split(train_and_val_set, test_size=(2/9))

len(train_set), len(val_set), len(test_set)
# Out:
# (560, 160, 80)

# %%
# Create the molecule_images directory if it doesn't exist
output_dir = './composite_images'
if not os.path.exists(output_dir): os.mkdir(output_dir)

train_dir = os.path.join(output_dir, 'train') 
val_dir   = os.path.join(output_dir, 'val') 
test_dir  = os.path.join(output_dir, 'test') 

# Create the sub-directories
for d in [train_dir, val_dir, test_dir]:
    if not os.path.exists(d): os.mkdir(d)
    
    images_sub_dir = os.path.join(d, 'images')
    labels_sub_dir = os.path.join(d, 'labels')
    
    for sub_dir in [images_sub_dir, labels_sub_dir]:
        if not os.path.exists(sub_dir): os.mkdir(sub_dir)

# %%
# make unified yolo tags 
tags = [tag]

# zip the dataset
dataset = [(train_dir, train_set),(val_dir, val_set),(test_dir, test_set)]

for d, s in dataset:
    images_sub_dir = os.path.join(d, 'images')
    labels_sub_dir = os.path.join(d, 'labels')

    # copy over the images
    for img in s:
        shutil.copyfile(img.path, os.path.join(images_sub_dir, img.name))
    
    # covert ImageJ labels to yolo format and save it to labels_sub_dir
    convert_to_yolo_format(s, labels_sub_dir, tags)
# Out:
# successfully generated labels for image  Sample3711.png
# successfully generated labels for image  Sample1777.png
# successfully generated labels for image  Sample4328.png
# successfully generated labels for image  Sample5437.png
# successfully generated labels for image  Sample4514.png
# successfully generated labels for image  Sample1311.png
# successfully generated labels for image  Sample3267.png
# successfully generated labels for image  Sample3135.png
# successfully generated labels for image  Sample5135.png
# successfully generated labels for image  Sample3692.png
# successfully generated labels for image  Sample2162.png
# successfully generated labels for image  Sample3589.png
# successfully generated labels for image  Sample5266.png
# successfully generated labels for image  Sample1101.png
# successfully generated labels for image  Sample2952.png
# successfully generated labels for image  Sample1504.png
# successfully generated labels for image  Sample4233.png
# successfully generated labels for image  Sample1706.png
# successfully generated labels for image  Sample1535.png
# successfully generated labels for image  Sample4426.png
# successfully generated labels for image  Sample1862.png
# successfully generated labels for image  Sample4724.png
# successfully generated labels for image  Sample3956.png
# successfully generated labels for image  Sample1387.png
# successfully generated labels for image  Sample1470.png
# successfully generated labels for image  Sample2788.png
# successfully generated labels for image  Sample2097.png
# successfully generated labels for image  Sample2681.png
# successfully generated labels for image  Sample1964.png
# successfully generated labels for image  Sample2027.png
# successfully generated labels for image  Sample4758.png
# successfully generated labels for image  Sample1645.png
# successfully generated labels for image  Sample3035.png
# successfully generated labels for image  Sample2475.png
# successfully generated labels for image  Sample4339.png
# successfully generated labels for image  Sample1235.png
# successfully generated labels for image  Sample5717.png
# successfully generated labels for image  Sample3436.png
# successfully generated labels for image  Sample2616.png
# successfully generated labels for image  Sample1488.png
# successfully generated labels for image  Sample3496.png
# successfully generated labels for image  Sample5251.png
# successfully generated labels for image  Sample6029.png
# successfully generated labels for image  Sample1269.png
# successfully generated labels for image  Sample5342.png
# successfully generated labels for image  Sample5939.png
# successfully generated labels for image  Sample5952.png
# successfully generated labels for image  Sample5948.png
# successfully generated labels for image  Sample3951.png
# successfully generated labels for image  Sample1315.png
# successfully generated labels for image  Sample1204.png
# successfully generated labels for image  Sample2671.png
# successfully generated labels for image  Sample3043.png
# successfully generated labels for image  Sample1975.png
# successfully generated labels for image  Sample4183.png
# successfully generated labels for image  Sample1555.png
# successfully generated labels for image  Sample1494.png
# successfully generated labels for image  Sample3333.png
# successfully generated labels for image  Sample5564.png
# successfully generated labels for image  Sample1896.png
# successfully generated labels for image  Sample1481.png
# successfully generated labels for image  Sample2042.png
# successfully generated labels for image  Sample1216.png
# successfully generated labels for image  Sample5825.png
# successfully generated labels for image  Sample5068.png
# successfully generated labels for image  Sample5795.png
# successfully generated labels for image  Sample5465.png
# successfully generated labels for image  Sample1385.png
# successfully generated labels for image  Sample1344.png
# successfully generated labels for image  Sample4489.png
# successfully generated labels for image  Sample4072.png
# successfully generated labels for image  Sample4967.png
# successfully generated labels for image  Sample3116.png
# successfully generated labels for image  Sample6006.png
# successfully generated labels for image  Sample3561.png
# successfully generated labels for image  Sample3487.png
# successfully generated labels for image  Sample2776.png
# successfully generated labels for image  Sample5221.png
# successfully generated labels for image  Sample2698.png
# successfully generated labels for image  Sample1738.png
# successfully generated labels for image  Sample3969.png
# successfully generated labels for image  Sample2063.png
# successfully generated labels for image  Sample5711.png
# successfully generated labels for image  Sample3011.png
# successfully generated labels for image  Sample2874.png
# successfully generated labels for image  Sample2537.png
# successfully generated labels for image  Sample3949.png
# successfully generated labels for image  Sample5449.png
# successfully generated labels for image  Sample4437.png
# successfully generated labels for image  Sample1856.png
# successfully generated labels for image  Sample3224.png
# successfully generated labels for image  Sample3379.png
# successfully generated labels for image  Sample1300.png
# successfully generated labels for image  Sample5775.png
# successfully generated labels for image  Sample1390.png
# successfully generated labels for image  Sample1167.png
# successfully generated labels for image  Sample3439.png
# successfully generated labels for image  Sample1876.png
# successfully generated labels for image  Sample1911.png
# successfully generated labels for image  Sample5518.png
# successfully generated labels for image  Sample5260.png
# successfully generated labels for image  Sample4497.png
# successfully generated labels for image  Sample5522.png
# successfully generated labels for image  Sample1854.png
# successfully generated labels for image  Sample2637.png
# successfully generated labels for image  Sample3486.png
# successfully generated labels for image  Sample5183.png
# successfully generated labels for image  Sample4445.png
# successfully generated labels for image  Sample2598.png
# successfully generated labels for image  Sample5719.png
# successfully generated labels for image  Sample2223.png
# successfully generated labels for image  Sample4182.png
# successfully generated labels for image  Sample5551.png
# successfully generated labels for image  Sample5602.png
# successfully generated labels for image  Sample3302.png
# successfully generated labels for image  Sample3818.png
# successfully generated labels for image  Sample2934.png
# successfully generated labels for image  Sample2180.png
# successfully generated labels for image  Sample3407.png
# successfully generated labels for image  Sample1807.png
# successfully generated labels for image  Sample5353.png
# successfully generated labels for image  Sample5003.png
# successfully generated labels for image  Sample6117.png
# successfully generated labels for image  Sample2230.png
# successfully generated labels for image  Sample3434.png
# successfully generated labels for image  Sample1922.png
# successfully generated labels for image  Sample1794.png
# successfully generated labels for image  Sample3723.png
# successfully generated labels for image  Sample5600.png
# successfully generated labels for image  Sample3922.png
# successfully generated labels for image  Sample3479.png
# successfully generated labels for image  Sample1673.png
# successfully generated labels for image  Sample3967.png
# successfully generated labels for image  Sample2094.png
# successfully generated labels for image  Sample3484.png
# successfully generated labels for image  Sample4162.png
# successfully generated labels for image  Sample2894.png
# successfully generated labels for image  Sample2098.png
# successfully generated labels for image  Sample1051.png
# successfully generated labels for image  Sample2172.png
# successfully generated labels for image  Sample3489.png
# successfully generated labels for image  Sample5030.png
# successfully generated labels for image  Sample1173.png
# successfully generated labels for image  Sample2405.png
# successfully generated labels for image  Sample3020.png
# successfully generated labels for image  Sample3208.png
# successfully generated labels for image  Sample1954.png
# successfully generated labels for image  Sample4468.png
# successfully generated labels for image  Sample4908.png
# successfully generated labels for image  Sample2733.png
# successfully generated labels for image  Sample1940.png
# successfully generated labels for image  Sample5833.png
# successfully generated labels for image  Sample3754.png
# successfully generated labels for image  Sample1612.png
# successfully generated labels for image  Sample3411.png
# successfully generated labels for image  Sample2235.png
# successfully generated labels for image  Sample5746.png
# successfully generated labels for image  Sample5411.png
# successfully generated labels for image  Sample1123.png
# successfully generated labels for image  Sample3085.png
# successfully generated labels for image  Sample4593.png
# successfully generated labels for image  Sample3735.png
# successfully generated labels for image  Sample1583.png
# successfully generated labels for image  Sample5544.png
# successfully generated labels for image  Sample1240.png
# successfully generated labels for image  Sample3170.png
# successfully generated labels for image  Sample2516.png
# successfully generated labels for image  Sample2367.png
# successfully generated labels for image  Sample5607.png
# successfully generated labels for image  Sample3822.png
# successfully generated labels for image  Sample3790.png
# successfully generated labels for image  Sample5227.png
# successfully generated labels for image  Sample3467.png
# successfully generated labels for image  Sample1805.png
# successfully generated labels for image  Sample1769.png
# successfully generated labels for image  Sample2592.png
# successfully generated labels for image  Sample2510.png
# successfully generated labels for image  Sample6168.png
# successfully generated labels for image  Sample5963.png
# successfully generated labels for image  Sample3537.png
# successfully generated labels for image  Sample2604.png
# successfully generated labels for image  Sample5288.png
# successfully generated labels for image  Sample1690.png
# successfully generated labels for image  Sample2140.png
# successfully generated labels for image  Sample2895.png
# successfully generated labels for image  Sample2800.png
# successfully generated labels for image  Sample4063.png
# successfully generated labels for image  Sample4111.png
# successfully generated labels for image  Sample3815.png
# successfully generated labels for image  Sample4650.png
# successfully generated labels for image  Sample2025.png
# successfully generated labels for image  Sample2696.png
# successfully generated labels for image  Sample1544.png
# successfully generated labels for image  Sample6021.png
# successfully generated labels for image  Sample4029.png
# successfully generated labels for image  Sample5810.png
# successfully generated labels for image  Sample1708.png
# successfully generated labels for image  Sample1563.png
# successfully generated labels for image  Sample3342.png
# successfully generated labels for image  Sample1493.png
# successfully generated labels for image  Sample5455.png
# successfully generated labels for image  Sample3678.png
# successfully generated labels for image  Sample2023.png
# successfully generated labels for image  Sample3835.png
# successfully generated labels for image  Sample2504.png
# successfully generated labels for image  Sample4022.png
# successfully generated labels for image  Sample1252.png
# successfully generated labels for image  Sample5250.png
# successfully generated labels for image  Sample1443.png
# successfully generated labels for image  Sample3119.png
# successfully generated labels for image  Sample3876.png
# successfully generated labels for image  Sample4884.png
# successfully generated labels for image  Sample6177.png
# successfully generated labels for image  Sample4540.png
# successfully generated labels for image  Sample3077.png
# successfully generated labels for image  Sample4408.png
# successfully generated labels for image  Sample1317.png
# successfully generated labels for image  Sample4944.png
# successfully generated labels for image  Sample3382.png
# successfully generated labels for image  Sample4567.png
# successfully generated labels for image  Sample3351.png
# successfully generated labels for image  Sample5386.png
# successfully generated labels for image  Sample4423.png
# successfully generated labels for image  Sample2950.png
# successfully generated labels for image  Sample3592.png
# successfully generated labels for image  Sample3550.png

# %%
# generate yolo yaml file
yolo_yaml = os.path.join(output_dir, 'molecule_detection_yolov5.yaml')

with open(yolo_yaml, 'w') as yamlout:
    yaml.dump(
        {'train': train_dir,
         'val': val_dir,
         'nc': len(tags),
         'names': tags},
        yamlout,
        default_flow_style=None,
        sort_keys=False
    )

# %%
# %run yolov5/train.py --img 640 --batch 16 --epochs 1 --data ./composite_images/molecule_detection_yolov5.yaml --weights yolov5s.pt
# Out:
# YOLOv5  2021-5-13 torch 1.8.1+cpu CPU
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='./composite_images/molecule_detection_yolov5.yaml', device='', entity=None, epochs=1, evolve=False, exist_ok=False, global_rank=-1, hyp='.\\yolov5\\data\\hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs\\train\\exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# github: skipping check (not a git repository)
# requirements: requirements.txt not found, check failed.
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning 'composite_images\train\labels' images and labels... 560 found, 0 missing, 0 empty, 0 corrupted: 100%|█
# train: New cache created: composite_images\train\labels.cache
# val: Scanning 'composite_images\val\labels' images and labels... 160 found, 0 missing, 0 empty, 0 corrupted: 100%|█| 16
# val: New cache created: composite_images\val\labels.cache
# Plotting labels...
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9634:  44%|██▋   | 445/1000 [00:00<00:00, 4281.30it/s]
# autoanchor: Analyzing anchors... anchors/target = 2.26, Best Possible Recall (BPR) = 0.4902. Attempting to improve anchors, please wait...
# autoanchor: WARNING: Extremely small objects found. 287 of 563 labels are < 3 pixels in size.
# autoanchor: Running kmeans for 9 anchors on 276 points...
# autoanchor: thr=0.25: 0.4902 best possible recall, 3.88 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.286/0.471-mean/best, past_thr=0.656-mean: 8,29,  109,44,  130,45,  159,46,  104,89,  172,61,  135,96,  161,104,  157,113
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.9651: 100%|█████| 1000/1000 [00:00<00:00, 4213.75it/s]
# Image sizes 640 train, 640 test
# Using 8 dataloader workers
# Logging results to runs\train\exp
# Starting training for 1 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#   0%|                                                                                           | 0/35 [00:00<?, ?it/s]
# autoanchor: thr=0.25: 0.4902 best possible recall, 3.88 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.285/0.473-mean/best, past_thr=0.653-mean: 8,29,  104,43,  130,45,  158,45,  103,93,  174,59,  136,94,  157,108,  156,112
# autoanchor: Original anchors better than new anchors. Proceeding with original anchors.
#        0/0        0G   0.09634   0.02174         0    0.1181        16       640: 100%|█| 35/35 [04:22<00:00,  7.50s/it
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|█| 5/5 [00:21<00:00,
#                  all         160         161     0.00543       0.087     0.00188    0.000273
# 1 epochs completed in 0.079 hours.
# Optimizer stripped from runs\train\exp\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\exp\weights\best.pt, 14.4MB

# %%
from azureml.core import Workspace, Experiment, Environment, ScriptRunConfig
from azureml.core.conda_dependencies import CondaDependencies

# %%
yolov5_env = Environment(name="yolov5_env")

yolov5_env.docker.base_image  = "mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04"

conda_dep = CondaDependencies()
conda_dep.add_conda_package('python=3.8')

# install all the yolov5 requirement at the image build time
with open('./yolov5/requirements.txt', 'r') as f:
    line = f.readline()
    
    while line != '':        
        if line.startswith('#') or len(line.split()) == 0:
            line = f.readline()
            continue
        
        conda_dep.add_pip_package(line.split()[0])
        line = f.readline()

yolov5_env.python.conda_dependencies=conda_dep

# %%
yolov5_env.get_image_details
# Out:
# <bound method Environment.get_image_details of {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi4.1.0-cuda11.0.3-cudnn8-ubuntu18.04",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": "2g"
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "yolov5_env",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.8",
#                 {
#                     "pip": [
#                         "azureml-defaults",
#                         "matplotlib>=3.2.2",
#                         "numpy>=1.18.5",
#                         "opencv-python>=4.1.2",
#                         "Pillow",
#                         "PyYAML>=5.3.1",
#                         "scipy>=1.4.1",
#                         "torch>=1.7.0",
#                         "torchvision>=0.8.1",
#                         "tqdm>=4.41.0",
#                         "tensorboard>=2.4.1",
#                         "seaborn>=0.11.0",
#                         "pandas",
#                         "thop",
#                         "pycocotools>=2.0"
#                     ]
#                 }
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": null
# }>

# %%
subscription_id = 'cfa7347c-f784-4a8a-b07f-e7f4b066c74c'
resource_group  = 'rg-amlclass-ktsh99'
workspace_name  = 'aml-amlclass-ktsh99'
ws = Workspace(subscription_id, resource_group, workspace_name)

experiment = Experiment(workspace=ws, name='composite_detection_yolo_training')

# %%
# Overall configuration for the script to be run on the compute cluster
config = ScriptRunConfig(source_directory='./deploy_yolo_training/',   ## folder in which the script is located
                         script='training_on_aml.py',       ## script name
                         compute_target='GPU-ktsh99',
                         environment=yolov5_env)

# %%
# %pwd
# Out:
# 'C:\\Users\\kadis\\OneDrive\\Documents\\Hack_Week'

# %%
run = experiment.submit(config)
aml_url = run.get_portal_url()
print(aml_url)
# Out:
# https://ml.azure.com/runs/composite_detection_yolo_training_1620921256_c456a2a4?wsid=/subscriptions/cfa7347c-f784-4a8a-b07f-e7f4b066c74c/resourcegroups/rg-amlclass-ktsh99/workspaces/aml-amlclass-ktsh99&tid=f6b6dd5b-f02f-441a-99a0-162ac5060bd2
